# %%
import pandas as pd

# %%
df_price = pd.read_csv("trader_joes - trader_joes.csv")
df_usda = pd.read_csv("USDA-305tj(Sheet1).csv")

# %%
print("df_price columns:", df_price.columns)
print("df_usda columns:", df_usda.columns)
df_price.head()
df_usda.head()
# Out:
# df_price columns: Index(['Unnamed: 0', 'fdc_id', 'brand_owner', 'brand_name', 'subbrand_name',
#        'GTIN/UPC', 'ingredients', 'not_a_significant_source_of',
#        'serving_size', 'serving_size_unit', 'household_serving_fulltext',
#        'branded_food_category', 'data_source', 'package_weight',
#        'modified_date', 'available_date', 'market_country',
#        'discontinued_date', 'preparation_state_code', 'trade_channel',
#        'short_description', 'material_code'],
#       dtype='object')
# df_usda columns: Index(['GTIN/UPC', 'Name', 'Branded Food Category', 'Brand Owner', 'Brand',
#        'Market Country', 'Price', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')
#    GTIN/UPC                                           Name  \
# 0  502627.0                            ORGANIC BLACK BEANS
# 1  344753.0          TRADER JOE'S, SPARKLING MINERAL WATER
# 2  345347.0  TRADER JOE'S, SPARKLING MINERAL WATER, ORANGE
# ...

# %%
df_price.rename(columns={"gtin_upc":"GTIN/UPC"}, inplace=True)
df_merged = pd.merge(df_price, df_usda, how="inner", on="GTIN/UPC")

# %%
df_merged.info()
df_merged.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797 entries, 0 to 796
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   797 non-null    int64
#  1   fdc_id                       797 non-null    int64
#  2   brand_owner                  797 non-null    object
#  3   brand_name                   594 non-null    object
#  4   subbrand_name                0 non-null      float64
#  5   GTIN/UPC                     797 non-null    int64
#  6   ingredients                  796 non-null    object
#  7   not_a_significant_source_of  10 non-null     object
#  8   serving_size                 797 non-null    float64
#  9   serving_size_unit            797 non-null    object
#  10  household_serving_fulltext   232 non-null    object
#  11  branded_food_category        797 non-null    object
#  12  data_source                  797 non-null    object
# ...
