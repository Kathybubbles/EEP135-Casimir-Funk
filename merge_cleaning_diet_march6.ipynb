# %% [markdown]
#  # Merging Datasets, Cleaning and Filtering Dataframe, & Diet Function

# %%
# Importing packages
import pandas as pd
import re

# %%
# Creating and cleaning data
def drop_nan_columns(df):
    # Drop columns where all values are NaN
    df_cleaned = df.dropna(axis=1, how='all')
    return df_cleaned

# USDA Data for Prices
usda_data = pd.read_csv("USDA-305tj(Sheet1).csv")
# Trader Joes Data for Ingredients
tj_data = pd.read_csv('trader_joes.csv')
tj_data.rename(columns={"gtin_upc":"GTIN/UPC"}, inplace=True)

# Merging data
merged_data = pd.merge(usda_data, tj_data, how = 'outer', on = 'GTIN/UPC' )
merged_data = drop_nan_columns(merged_data)

# Data of complete pricing
completed_prices = pd.read_csv("EEP153_COMPLETED_PRICES.csv")
completed_prices['GTIN/UPC'] = completed_prices['GTIN/UPC'].astype(int)

# Dropping unneeded columns and duplicates
not_needed = ['branded_food_category', 'data_source', 'modified_date',
            'available_date', 'market_country', 'Unnamed: 0', 'brand_owner', 'Market Country',
            'brand_name', 'Brand Owner', 'Brand', 'fdc_id']

merged_data_drop = merged_data.drop(not_needed, axis = 1)
merged_data_drop.drop_duplicates()

# Setting index, and cleaning data
merged_data_drop = merged_data_drop.set_index('Name')
merged_data_clean =  merged_data_drop[merged_data_drop.index.notna()]
merged_data_clean = merged_data_clean.reset_index().drop(['Price', 'Name'], axis = 1)
merged_data_clean = merged_data_clean[~merged_data_clean['GTIN/UPC'].duplicated(keep='first')]

# Final data frame, before cleaning
final_data = pd.merge(completed_prices, merged_data_clean, on = 'GTIN/UPC', how = 'left')

# Cleaning Data Frame
final_data['ingredients'] = final_data.apply(
    lambda row: f"{row['ingredients_x']}, {row['ingredients_y']}" if pd.notna(row['ingredients_x']) and pd.notna(row['ingredients_y']) 
    else row['ingredients_x'] if pd.notna(row['ingredients_x']) 
    else row['ingredients_y'], axis=1
)

# Filling in missing ingredients
fill_ingredients = ['WHEAT FLOUR, SUGAR, SALT, BARLEY MALT SYRUP',\
                     'POPCORN, SUNFLOWER OIL, SUGAR, SALT', 'SOLID WHITE TUNA, WATER, SALT']

final_data.loc[final_data['ingredients'].isna(), 'ingredients'] = fill_ingredients
final_data = final_data.drop(['ingredients_x', 'ingredients_y'], axis = 1).set_index('Name')

# Final dataset
final_data
# Out:
#                                              GTIN/UPC  Price  \
# Name
# POTATO CHIPS, SEA SALT                           5487   3.99
# TRADER JOE'S, CORNICHONS                         6163   2.99
# ORGANIC TOMATOES, DICED IN TOMATO JUICE         10894   1.99
# REDUCED FAT MAYO DRESSING                       14816   4.99
# PEANUT BUTTER, CRUNCHY SALTED                   14885   2.49
# ...                                               ...    ...
# SALTED CARAMEL GELATO                      5100000875   3.79
# GROUND BEEF                               41498112103   7.49
# WISCONSIN SHARP CHEDDAR CHEESE           227871000000   4.99
# COCONUT OIL                              750456000000   4.99
# HALEY BLEND WITH COCONUT OIL             869210000000   4.99
#
#                                                        Branded Food Category  \
# Name
# POTATO CHIPS, SEA SALT                              Chips, Pretzels & Snacks
# TRADER JOE'S, CORNICHONS                 Pickles, Olives, Peppers & Relishes
# ORGANIC TOMATOES, DICED IN TOMATO JUICE                             Tomatoes
# REDUCED FAT MAYO DRESSING                        Salad Dressing & Mayonnaise
# PEANUT BUTTER, CRUNCHY SALTED                             Nut & Seed Butters
# ...                                                                      ...
# SALTED CARAMEL GELATO                              Ice Cream & Frozen Yogurt
# GROUND BEEF                                                      Other Meats
# WISCONSIN SHARP CHEDDAR CHEESE                                        Cheese
# COCONUT OIL                                         Vegetable & Cooking Oils
# HALEY BLEND WITH COCONUT OIL                                          Cereal
#
#                                         not_a_significant_source_of  \
# Name
# POTATO CHIPS, SEA SALT                                          NaN
# TRADER JOE'S, CORNICHONS                                        NaN
# ORGANIC TOMATOES, DICED IN TOMATO JUICE                         NaN
# REDUCED FAT MAYO DRESSING                                       NaN
# PEANUT BUTTER, CRUNCHY SALTED                                   NaN
# ...                                                             ...
# SALTED CARAMEL GELATO                                           NaN
# GROUND BEEF                                                     NaN
# WISCONSIN SHARP CHEDDAR CHEESE                                  NaN
# COCONUT OIL                                                     NaN
# HALEY BLEND WITH COCONUT OIL                                    NaN
#
#                                          serving_size serving_size_unit  \
# Name
# POTATO CHIPS, SEA SALT                           28.0                 g
# TRADER JOE'S, CORNICHONS                         28.0                 g
# ORGANIC TOMATOES, DICED IN TOMATO JUICE         130.0                 g
# REDUCED FAT MAYO DRESSING                        15.0                 g
# PEANUT BUTTER, CRUNCHY SALTED                    32.0                 g
# ...                                               ...               ...
# SALTED CARAMEL GELATO                            99.0                 g
# GROUND BEEF                                     112.0                 g
# WISCONSIN SHARP CHEDDAR CHEESE                    NaN               NaN
# COCONUT OIL                                       NaN               NaN
# HALEY BLEND WITH COCONUT OIL                      NaN               NaN
#
#                                         household_serving_fulltext  \
# Name
# POTATO CHIPS, SEA SALT                                       1 ONZ
# TRADER JOE'S, CORNICHONS                                     1 ONZ
# ORGANIC TOMATOES, DICED IN TOMATO JUICE                    0.5 cup
# REDUCED FAT MAYO DRESSING                                      NaN
# PEANUT BUTTER, CRUNCHY SALTED                                  NaN
# ...                                                            ...
# SALTED CARAMEL GELATO                                      0.5 cup
# GROUND BEEF                                                  4 ONZ
# WISCONSIN SHARP CHEDDAR CHEESE                                 NaN
# COCONUT OIL                                                    NaN
# HALEY BLEND WITH COCONUT OIL                                   NaN
#
#                                             package_weight  \
# Name
# POTATO CHIPS, SEA SALT                                 NaN
# TRADER JOE'S, CORNICHONS                               NaN
# ORGANIC TOMATOES, DICED IN TOMATO JUICE                NaN
# REDUCED FAT MAYO DRESSING                              NaN
# PEANUT BUTTER, CRUNCHY SALTED            16 oz/1 lbs/454 g
# ...                                                    ...
# SALTED CARAMEL GELATO                                  NaN
# GROUND BEEF                                            NaN
# WISCONSIN SHARP CHEDDAR CHEESE                         NaN
# COCONUT OIL                                            NaN
# HALEY BLEND WITH COCONUT OIL                           NaN
#
#                                                                                ingredients
# Name
# POTATO CHIPS, SEA SALT                         UNPEELED POTATOES, SUNFLOWER OIL, SEA SALT.
# TRADER JOE'S, CORNICHONS                 GHERKINS (CUCUMBERS), WATER, VINEGAR, SALT, ON...
# ORGANIC TOMATOES, DICED IN TOMATO JUICE  ORGANIC TOMATOES, ORGANIC TOMATO JUICE FROM CO...
# REDUCED FAT MAYO DRESSING                WATER, EXPELLER PRESSED CANOLA OIL, CORNSTARCH...
# PEANUT BUTTER, CRUNCHY SALTED                                  DRY ROASTED PEANUTS, SALT.
# ...                                                                                    ...
# SALTED CARAMEL GELATO                    SKIM MILK, CREAM, GLUCOSE SYRUP (CORN), CANE S...
# GROUND BEEF                                                                   GROUND BEEF.
# WISCONSIN SHARP CHEDDAR CHEESE           PASTEURIZED MILK, CHEESE CULTURES, SALT, VEGET...
# COCONUT OIL                                                                        COCONUT
# HALEY BLEND WITH COCONUT OIL                                                       COCONUT
#
# [305 rows x 9 columns]

# %%
# Function to filter out dataframe depending on certain strings
def remove_rows(df, column_name, search_strings):
    # Convert all values in the specified column to strings
    df[column_name] = df[column_name].apply(lambda x: str(x) if x is not None else "")
    # Create a regex pattern to match any of the search strings as whole words
    search_pattern = r'|'.join([r'\b' + re.escape(search_string) + r'\b' for search_string in search_strings])
    # Filtering out rows where the column contains any of the search strings
    df_filtered = df[~df[column_name].str.contains(search_pattern, case=False, na=False, regex=True)]
    return df_filtered

# Vegetarian Example
meats_and_fish = ['CHICKEN', 'BEEF', 'HAM', 'PORK', 'FISH', 'TURKEY', 'SALMON', 'TUNA']
remove_rows(final_data, 'ingredients', meats_and_fish)

# Vegan Example
animal_products = ['CHICKEN', 'BEEF', 'HAM', 'PORK', 'FISH','TURKEY', 'SALMON', 'TUNA',
                    'MILK', 'BUTTER', 'EGG', 'EGGS', 'HONEY', 'CHEESE', 'YOGURT', 'CREAM', 'GELATINE']

remove_rows(final_data, 'ingredients', animal_products)

# Function to keep certain values depending on certain strings
def keep_rows(df, column_name, search_strings):
    # Converts all values to strings
    df[column_name] = df[column_name].apply(lambda x: str(x) if x is not None else "")
    # Create a regex pattern for exact matches
    search_pattern = r'|'.join([r'\b' + re.escape(search_string) + r'\b' for search_string in search_strings])
    # Filter rows where the column matches any of the exact strings in search_strings
    filtered_df = df[df[column_name].str.contains(search_pattern, case=False, na=False)]
    return filtered_df

# Carnivore example
keep_rows(final_data, 'ingredients', meats_and_fish)
# Out:
#                                                        GTIN/UPC  Price  \
# Name
# WILD ALASKAN PINK SALMON                                  35927   3.99
# PREMIUM CHUNK WHITE CHICKEN IN BROTH                      38409   1.99
# TRADER JOE'S, MUSHROOM & HERB RISOTTO                     99080   3.79
# TRADER JOE'S, PREMIUM CHUNK WHITE CHICKEN IN WATER       434652   3.99
# TURKEY CHILI WITH BEANS                                  479363   2.69
# TRADER JOE'S, UNCURED BACON JAM, BACON, BACON            545198   4.49
# OVEN ROASTED TURKEY BREAST                               815949   5.99
# TRADER JOE'S, SMOKED TURKEY BREAST                       815963   5.99
# UNCURED BLACK FOREST HAM                                 868631   4.69
# TRADER JOE'S, SAVORY BROTH, CHICKEN, CHICKEN             908597   1.99
# TRADER JOE'S, ALBACORE TUNA IN WATER                     958363   1.99
# TURKEY JERKY                                             959742  13.25
# TRADER JOE'S, CHICKEN NOODLE SOUP WITH VEGGIES           984645   2.99
# GROUND BEEF                                         41498112103   7.49
#
#                                                             Branded Food Category  \
# Name
# WILD ALASKAN PINK SALMON                                           Canned Seafood
# PREMIUM CHUNK WHITE CHICKEN IN BROTH                                  Canned Meat
# TRADER JOE'S, MUSHROOM & HERB RISOTTO                                        Rice
# TRADER JOE'S, PREMIUM CHUNK WHITE CHICKEN IN WATER                    Canned Meat
# TURKEY CHILI WITH BEANS                                              Chili & Stew
# TRADER JOE'S, UNCURED BACON JAM, BACON, BACON                         Canned Meat
# OVEN ROASTED TURKEY BREAST                          Pepperoni, Salami & Cold Cuts
# TRADER JOE'S, SMOKED TURKEY BREAST                  Pepperoni, Salami & Cold Cuts
# UNCURED BLACK FOREST HAM                            Pepperoni, Salami & Cold Cuts
# TRADER JOE'S, SAVORY BROTH, CHICKEN, CHICKEN                          Canned Soup
# TRADER JOE'S, ALBACORE TUNA IN WATER                                  Canned Tuna
# TURKEY JERKY                                                         Other Snacks
# TRADER JOE'S, CHICKEN NOODLE SOUP WITH VEGGIES                        Other Soups
# GROUND BEEF                                                           Other Meats
#
#                                                                           not_a_significant_source_of  \
# Name
# WILD ALASKAN PINK SALMON                                                                          NaN
# PREMIUM CHUNK WHITE CHICKEN IN BROTH                                                              NaN
# TRADER JOE'S, MUSHROOM & HERB RISOTTO                                                             NaN
# TRADER JOE'S, PREMIUM CHUNK WHITE CHICKEN IN WATER                                                NaN
# TURKEY CHILI WITH BEANS                                                                           NaN
# TRADER JOE'S, UNCURED BACON JAM, BACON, BACON                                                     NaN
# OVEN ROASTED TURKEY BREAST                                                                        NaN
# TRADER JOE'S, SMOKED TURKEY BREAST                                                                NaN
# UNCURED BLACK FOREST HAM                                                                          NaN
# TRADER JOE'S, SAVORY BROTH, CHICKEN, CHICKEN        NOT A SIGNIFICANT SOURCE OF TRANS FAT, DIETARY...
# TRADER JOE'S, ALBACORE TUNA IN WATER                                                              NaN
# TURKEY JERKY                                                                                      NaN
# TRADER JOE'S, CHICKEN NOODLE SOUP WITH VEGGIES                                                    NaN
# GROUND BEEF                                                                                       NaN
#
#                                                     serving_size  \
# Name
# WILD ALASKAN PINK SALMON                                    63.0
# PREMIUM CHUNK WHITE CHICKEN IN BROTH                        61.0
# TRADER JOE'S, MUSHROOM & HERB RISOTTO                       42.0
# TRADER JOE'S, PREMIUM CHUNK WHITE CHICKEN IN WATER          71.0
# TURKEY CHILI WITH BEANS                                    247.0
# TRADER JOE'S, UNCURED BACON JAM, BACON, BACON               15.0
# OVEN ROASTED TURKEY BREAST                                  56.0
# TRADER JOE'S, SMOKED TURKEY BREAST                          56.0
# UNCURED BLACK FOREST HAM                                    56.0
# TRADER JOE'S, SAVORY BROTH, CHICKEN, CHICKEN                 9.6
# TRADER JOE'S, ALBACORE TUNA IN WATER                        56.0
# TURKEY JERKY                                                28.0
# TRADER JOE'S, CHICKEN NOODLE SOUP WITH VEGGIES             245.0
# GROUND BEEF                                                112.0
#
#                                                    serving_size_unit  \
# Name
# WILD ALASKAN PINK SALMON                                           g
# PREMIUM CHUNK WHITE CHICKEN IN BROTH                               g
# TRADER JOE'S, MUSHROOM & HERB RISOTTO                              g
# TRADER JOE'S, PREMIUM CHUNK WHITE CHICKEN IN WATER                 g
# TURKEY CHILI WITH BEANS                                            g
# TRADER JOE'S, UNCURED BACON JAM, BACON, BACON                      g
# OVEN ROASTED TURKEY BREAST                                         g
# TRADER JOE'S, SMOKED TURKEY BREAST                                 g
# UNCURED BLACK FOREST HAM                                           g
# TRADER JOE'S, SAVORY BROTH, CHICKEN, CHICKEN                       g
# TRADER JOE'S, ALBACORE TUNA IN WATER                               g
# TURKEY JERKY                                                       g
# TRADER JOE'S, CHICKEN NOODLE SOUP WITH VEGGIES                     g
# GROUND BEEF                                                        g
#
#                                                    household_serving_fulltext  \
# Name
# WILD ALASKAN PINK SALMON                                                  NaN
# PREMIUM CHUNK WHITE CHICKEN IN BROTH                                      NaN
# TRADER JOE'S, MUSHROOM & HERB RISOTTO                                     NaN
# TRADER JOE'S, PREMIUM CHUNK WHITE CHICKEN IN WATER                   0.33 cup
# TURKEY CHILI WITH BEANS                                                 1 cup
# TRADER JOE'S, UNCURED BACON JAM, BACON, BACON                          1 Tbsp
# OVEN ROASTED TURKEY BREAST                                                NaN
# TRADER JOE'S, SMOKED TURKEY BREAST                                        NaN
# UNCURED BLACK FOREST HAM                                                  NaN
# TRADER JOE'S, SAVORY BROTH, CHICKEN, CHICKEN                              NaN
# TRADER JOE'S, ALBACORE TUNA IN WATER                                    2 ONZ
# TURKEY JERKY                                                            1 ONZ
# TRADER JOE'S, CHICKEN NOODLE SOUP WITH VEGGIES                          1 cup
# GROUND BEEF                                                             4 ONZ
#
#                                                    package_weight  \
# Name
# WILD ALASKAN PINK SALMON                                      NaN
# PREMIUM CHUNK WHITE CHICKEN IN BROTH                          NaN
# TRADER JOE'S, MUSHROOM & HERB RISOTTO                         NaN
# TRADER JOE'S, PREMIUM CHUNK WHITE CHICKEN IN WATER            NaN
# TURKEY CHILI WITH BEANS                                       NaN
# TRADER JOE'S, UNCURED BACON JAM, BACON, BACON                 NaN
# OVEN ROASTED TURKEY BREAST                                    NaN
# TRADER JOE'S, SMOKED TURKEY BREAST                            NaN
# UNCURED BLACK FOREST HAM                                      NaN
# TRADER JOE'S, SAVORY BROTH, CHICKEN, CHICKEN        4.06 oz/115 g
# TRADER JOE'S, ALBACORE TUNA IN WATER                          NaN
# TURKEY JERKY                                                  NaN
# TRADER JOE'S, CHICKEN NOODLE SOUP WITH VEGGIES                NaN
# GROUND BEEF                                                   NaN
#
#                                                                                           ingredients
# Name
# WILD ALASKAN PINK SALMON                                                   ALASKAN PINK SALMON, SALT.
# PREMIUM CHUNK WHITE CHICKEN IN BROTH                              WHITE CHICKEN, CHICKEN BROTH, SALT.
# TRADER JOE'S, MUSHROOM & HERB RISOTTO               SUPERFINO ARBORIO RICE, ONIONS***, MUSHROOM***...
# TRADER JOE'S, PREMIUM CHUNK WHITE CHICKEN IN WATER                  CHICKEN BREAST MEAT, WATER, SALT.
# TURKEY CHILI WITH BEANS                             WATER, DARK TURKEY MEAT, BEANS (RED AND/OR PIN...
# TRADER JOE'S, UNCURED BACON JAM, BACON, BACON       COOKED APPLEWOOD SMOKED UNCURED BACON NO NITRA...
# OVEN ROASTED TURKEY BREAST                          TURKEY BREAST, WATER, CONTAINS LESS THAN 2% OF...
# TRADER JOE'S, SMOKED TURKEY BREAST                  TURKEY BREAST, WATER, CONTAINS LESS THAN 2% OF...
# UNCURED BLACK FOREST HAM                            PORK, WATER, VINEGAR, KOSHER SALT, TURBINADO S...
# TRADER JOE'S, SAVORY BROTH, CHICKEN, CHICKEN        CHICKEN STOCK, MALTODEXTRIN (CORN), NATURAL FL...
# TRADER JOE'S, ALBACORE TUNA IN WATER                                    SOLID WHITE TUNA, WATER, SALT
# TURKEY JERKY                                        TURKEY, SUGAR, WATER, SOY SAUCE (WATER, WHEAT,...
# TRADER JOE'S, CHICKEN NOODLE SOUP WITH VEGGIES      WATER, CHICKEN MEAT, CARROTS, CELERY, ONIONS, ...
# GROUND BEEF                                                                              GROUND BEEF.
