# %% [markdown]
# # Food Staples Costs for Each Diet -> Deliverable A: Presentation

# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Labels and Colors for Individual Bar Plots
labels = ['Trader Joes', 'Berkeley Bowl', 'Safeway']
bar_colors = ['tab:red', 'tab:blue', 'tab:orange']

# %%
# Allergen Free Diet Essentials: Trader Joe's Prices
allergen_free_tj = {'Rice': 3.29, 'Chicken': 6.99, 'Banana': 1.38, 
                    'Apple': 1.29 ,'Corn': 0.99, 'Tomato': 1.79}

# Allergen Free Diet Essentials: Berkeley Bowl's Prices
allergen_free_bb = {'Rice': 6.27, 'Chicken': 12.09, 'Banana': 5.94, 
                    'Apple': 0.597,'Corn': 3.29, 'Tomato': 0.216}

# Allergen Free Diet Essentials: Safeway's Prices
allergen_free_safeway = {'Rice': 6.72, 'Chicken': 4.99, 'Banana': 1.98, 
                         'Apple': 0.80 , 'Corn': 1.99,  'Tomato': 1.365}

# Placing all values into a list
allergen_free_tj_values = list(allergen_free_tj.values())
allergen_free_bb_values = list(allergen_free_bb.values())
allergen_free_safeway_values = list(allergen_free_safeway.values())

# Finding total of all our prices
allergen_free_tj_total = sum(allergen_free_tj_values)
allergen_free_bb_total = sum(allergen_free_bb_values)
allergen_free_safeway_total = sum(allergen_free_safeway_values)

# List of total
allergen_list = [allergen_free_tj_total, allergen_free_bb_total, allergen_free_safeway_total] 

# Showing final plot
fig, ax = plt.subplots()
bar_container = ax.bar(labels, allergen_list, color=bar_colors)
ax.set(ylabel='Total Cost in Dollars', title='Allergen Free Diet Cost by Store')
ax.bar_label(bar_container, fmt='{:,.0f}')
plt.show()

# %%
# Omnivore Diet Essentials: Trader Joe's Prices
omnivore_tj = {'Rice': 3.29, 'Wheat Bread': 2.49, 'Spaghetti': 0.99, 
               'Chicken': 6.99, 'Salmon': 9.99, 'Ground Beef': 4.99, 
               'Cheddar Cheese': 4.79, 'Greek Yogurt': 5.49,
                'Black Beans': 0.99, 'Russet Potatoes': 0.79, 'Apple': 1.29}

# Omnivore Diet Essentials: Berkeley Bowl Prices
omnivore_bb = {'Rice': 6.27, 'Wheat Bread': 5.89, 'Spaghetti': 2.79, 
               'Chicken': 12.09, 'Salmon': 10.99, 'Ground Beef': 6.09, 
               'Cheddar Cheese': 8.29, 'Greek Yogurt': 6.59,
                'Black Beans': 1.89, 'Russet Potatoes': 0.363, 'Apple': 0.597}

# Omnivore Diet Essentials: Safeway Prices
omnivore_safeway = {'Rice': 6.72, 'Wheat Bread': 5.49, 'Spaghetti': 2.79, 
               'Chicken': 4.99, 'Salmon': 9.99, 'Ground Beef': 5.99, 
               'Cheddar Cheese': 4.49, 'Greek Yogurt': 4.99,
                'Black Beans': 1.89, 'Russet Potatoes': 1.63, 'Apple': 0.80}

# Placing all values into a list
omnivore_tj_values = list(omnivore_tj.values())
omnivore_bb_values = list(omnivore_bb.values())
omnivore_safeway_values = list(omnivore_safeway.values())

# Finding totals of all of our prices
omnivore_tj_total = sum(omnivore_tj_values)
omnivore_bb_total = sum(omnivore_bb_values)
omnivore_safeway_total = sum(omnivore_safeway_values)

# Placing totals into a list 
omnivore_list = [omnivore_tj_total, omnivore_bb_total, omnivore_safeway_total] 

# Plotting final chart
fig, ax = plt.subplots()
bar_container = ax.bar(labels, omnivore_list, color=bar_colors)
ax.set(ylabel='Total Cost in Dollars', title='Omnivore Diet Cost by Store')
ax.bar_label(bar_container, fmt='{:,.0f}')
plt.show()

# %%
# Carnivore Diet Essentials: Trader Joe's Prices
carnivore_tj = {'Ribeye Steak': 14.99, 'Chicken': 6.99, 'Salmon': 9.99, 'Ground Beef': 4.99, 
               'Cheddar Cheese': 4.79, 'Eggs': 4.99, 'Bacon': 5.99, 'Butter': 3.99}

# Carnivore Diet Essentials: Berkeley Bowl Prices
carnivore_bb = {'Ribeye Steak': 23.09, 'Chicken': 12.09, 'Salmon': 10.99, 'Ground Beef': 6.09, 
               'Cheddar Cheese': 8.29, 'Eggs': 4.99, 'Bacon': 9.89, 'Butter': 7.69}

# Carnivore Diet Essentials: Safeway Prices
carnivore_safeway = {'Ribeye Steak': 12.99, 'Chicken': 6.99, 'Salmon': 9.99, 'Ground Beef': 5.99, 
               'Cheddar Cheese': 4.29, 'Eggs': 10.99, 'Bacon': 13.99, 'Butter': 7.99}

# Putting all values into lists
carnivore_tj_values = list(carnivore_tj.values())
carnivore_bb_values = list(carnivore_bb.values())
carnivore_safeway_values = list(carnivore_safeway.values())

# Finding totals of all of our prices
carnivore_tj_total = sum(carnivore_tj_values)
carnivore_bb_total = sum(carnivore_bb_values)
carnivore_safeway_total = sum(carnivore_safeway_values)

# List of our totals
carnivore_list = [carnivore_tj_total, carnivore_bb_total, carnivore_safeway_total] 

# Plotting final bar chart
fig, ax = plt.subplots()
bar_container = ax.bar(labels, carnivore_list, color=bar_colors)
ax.set(ylabel='Total Cost in Dollars', title='Carnivore Diet Cost by Store')
ax.bar_label(bar_container, fmt='{:,.0f}')
plt.show()

# %%
# Vegan Diet Essentials: Trader Joe's Prices
vegan_tj = {'Hummus': 2.99, 'Wheat Bread': 2.49, 'Spaghetti': 0.99, 
               'Sweet Potato': 0.89, 'Banana': 1.38, 'Tortilla Chips': 3.99, 
               'Tofu': 1.79, 'Soy Milk': 2.29,'Black Beans': 0.99, 
               'Granola': 3.99, 'Peanut Butter': 2.49}

# Vegan Diet Essentials: Berkeley Bowl Prices
vegan_bb = {'Hummus': 5.49, 'Wheat Bread': 5.89, 'Spaghetti': 2.79, 
               'Sweet Potato': 0.363, 'Banana': 5.94, 'Tortilla Chips': 5.79, 
               'Tofu': 2.79, 'Soy Milk': 4.09,'Black Beans': 1.89, 
               'Granola': 7.69, 'Peanut Butter': 4.39}

# Vegan Diet Essentials: Safeway Prices
vegan_safeway = {'Hummus': 5.99, 'Wheat Bread': 5.49, 'Spaghetti': 2.79, 
               'Sweet Potato': 1.99, 'Banana': 1.98, 'Tortilla Chips': 4.49, 
               'Tofu': 3.29, 'Soy Milk': 4.59,'Black Beans': 1.89, 
               'Granola': 3.99, 'Peanut Butter': 4.49}

# Values from each dictionary
vegan_tj_values = list(vegan_tj.values())
vegan_bb_values = list(vegan_bb.values())
vegan_safeway_values = list(vegan_safeway.values())

# Sum of our prices
vegan_tj_total = sum(vegan_tj_values)
vegan_bb_total = sum(vegan_bb_values)
vegan_safeway_total = sum(vegan_safeway_values)

# Putting totals into list
vegan_list = [vegan_tj_total, vegan_bb_total, vegan_safeway_total] 

# Plotting final chart
fig, ax = plt.subplots()
bar_container = ax.bar(labels, vegan_list, color=bar_colors)
ax.set(ylabel='Total Cost in Dollars', title='Vegan Diet Cost by Store')
ax.bar_label(bar_container, fmt='{:,.0f}')
plt.show()

# %%
# Vegetarian Essentials: Trader Joe's Prices
veg_tj = {'Hummus': 2.99, 'Wheat Bread': 2.49, 'Greek Yogurt': 5.49, 
               'Sweet Potato': 0.89, 'Banana': 1.38, 'Eggs': 4.99, 
               'Tofu': 1.79, 'Garbonzo Beans': 1.19,'Black Beans': 0.99, 
               'Oats': 2.99, 'Peanut Butter': 2.49}

# Vegetarian Essentials: Berkeley Bowl Prices
veg_bb = {'Hummus': 5.49, 'Wheat Bread': 5.89, 'Greek Yogurt': 6.59,
               'Sweet Potato': 0.363, 'Banana': 5.94, 'Eggs': 4.99,
               'Tofu': 2.79, 'Garbonzo Beans': 3.29,'Black Beans': 1.89, 
               'Oats': 1.44, 'Peanut Butter': 4.39}

# Vegetarian Essentials: Safeway Prices
veg_safeway = {'Hummus': 5.99, 'Wheat Bread': 5.49, 'Greek Yogurt': 4.99,
               'Sweet Potato': 1.99, 'Banana': 1.98, 'Eggs': 10.99,
               'Tofu': 3.29, 'Garbonzo Beans': 1.89,'Black Beans': 1.89, 
               'Oats': 5.99, 'Peanut Butter': 4.49}

# Values from each dictionary
veg_tj_values = list(veg_tj.values())
veg_bb_values = list(veg_bb.values())
veg_safeway_values = list(veg_safeway.values())

# Sum of our prices
veg_tj_total = sum(veg_tj_values)
veg_bb_total = sum(veg_bb_values)
veg_safeway_total = sum(veg_safeway_values)

# Placing totals into list
veg_list = [veg_tj_total, veg_bb_total, veg_safeway_total] 

# Plotting final chart
fig, ax = plt.subplots()
bar_container = ax.bar(labels, veg_list, color=bar_colors)
ax.set(ylabel='Total Cost in Dollars', title='Vegetarian Diet Cost by Store')
ax.bar_label(bar_container, fmt='{:,.0f}')
plt.show()

# %%
# High Fat & Low Carb Essentials Trader Joe's Prices
hflc_tj = {'Eggs': 4.99, 'Olive Oil': 10.99, 'Ground Beef': 4.99, 
               'Cheddar Cheese': 4.79, 'Butter': 3.99, 'Heavy Cream': 4.49, 
               'Dark Chocolate': 2.29, 'Spinach': 1.99,'Almonds': 5.99, 
               'Avocado': 1.75, 'Strawberries': 3.99}

# Keto Essentials Berkeley Bowl Prices
hflc_bb = {'Eggs': 4.99, 'Olive Oil': 15.39, 'Ground Beef': 6.09, 
               'Cheddar Cheese': 8.29, 'Butter': 7.69, 'Heavy Cream': 4.39, 
               'Dark Chocolate': 4.69, 'Spinach': 3.30,'Almonds': 7.69, 
               'Avocado': 1.99, 'Strawberries': 3.09}

# Keto Essentials Safeway Prices
hflc_safeway = {'Eggs': 10.99, 'Olive Oil': 18.49, 'Ground Beef': 5.99, 
               'Cheddar Cheese': 4.29, 'Butter': 7.99, 'Heavy Cream': 2.29, 
               'Dark Chocolate': 4.99, 'Spinach': 4.49,'Almonds': 7.99, 
               'Avocado': 2.00, 'Strawberries': 5.99}

# Values from each dictionary
hflc_tj_values = list(hflc_tj.values())
hflc_bb_values = list(hflc_bb.values())
hflc_safeway_values = list(hflc_safeway.values())

# Total from each diet
hflc_tj_total = sum(hflc_tj_values)
hflc_bb_total = sum(hflc_bb_values)
hflc_safeway_total = sum(hflc_safeway_values)

# Labels & Bar Colors
hflc_list = [hflc_tj_total, hflc_bb_total, hflc_safeway_total] 

# Plotting and Showing Bar Plot 
fig, ax = plt.subplots()
bar_container = ax.bar(labels, hflc_list, color=bar_colors)
ax.set(ylabel='Total Cost in Dollars', title='High Fat & Low Carb Diet Cost by Store')
ax.bar_label(bar_container, fmt='{:,.0f}')
plt.show()

# %%
# Dictionary for Combined Visualization

combined_visualization = {'Total Cost': [omnivore_tj_total, omnivore_bb_total, omnivore_safeway_total,
                                         veg_tj_total, veg_bb_total, veg_safeway_total,
                                         vegan_tj_total, vegan_bb_total, vegan_safeway_total,
                                         hflc_tj_total, hflc_bb_total, hflc_safeway_total,
                                         allergen_free_tj_total, allergen_free_bb_total, allergen_free_safeway_total,
                                         carnivore_tj_total, carnivore_bb_total, carnivore_safeway_total], \
                          'Diet': ['Omnivore', 'Omnivore', 'Omnivore',
                                   'Vegetarian','Vegetarian','Vegetarian',
                                   'Vegan','Vegan','Vegan',
                                   'High Fat & Low Carb','High Fat & Low Carb','High Fat & Low Carb',
                                   'Allergen Free', 'Allergen Free', 'Allergen Free',
                                   'Carnivore','Carnivore','Carnivore'], \
                            'Store': ['Trader Joes', 'Berkeley Bowl', 'Safeway',
                                      'Trader Joes', 'Berkeley Bowl', 'Safeway',
                                      'Trader Joes', 'Berkeley Bowl', 'Safeway',
                                      'Trader Joes', 'Berkeley Bowl', 'Safeway',
                                      'Trader Joes', 'Berkeley Bowl', 'Safeway',
                                      'Trader Joes', 'Berkeley Bowl', 'Safeway']}

# Putting dictionary into dataframe
totals_df = pd.DataFrame.from_dict(combined_visualization)

# Facetgrid to show all at once
totals_diet = sns.FacetGrid(totals_df, col="Diet", hue = 'Store', height=4, aspect=.5)
totals_diet.map(sns.barplot, "Store", "Total Cost", order=["Trader Joes", "Berkeley Bowl", "Safeway"])

# Rotates the x-axis to make it readable
for totals_diet in totals_diet.axes.flat:
    totals_diet.set_xticks(np.arange(0,3,1))
    totals_diet.set_xticklabels(totals_diet.get_xticklabels(), rotation=45)


# Adjust layout to prevent labels from overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Visuals for "Min Cost Diet" from each store

# Trader Joes Min Cost for Men
omnivore_min_tj_male = {'FROSTED SHREDDED BITE SIZE WHEATS': 2.99 * 0.833333, 'INNER BEAN SNACK': 1.50 * 4.258366, 
                   'FUJI APPLE SLICES': 2.99 * 0.144917, 'HIGH FIBER CEREAL': 0.366667, 'TACO SEASONING MIX': 0.99 * 0.192622}
veg_min_tj_male = {'FROSTED SHREDDED BITE SIZE WHEATS': 2.99 * 0.833333, 'INNER BEAN SNACK': 1.50 * 4.258366, 
                   'FUJI APPLE SLICES': 2.99 * 0.144917, 'HIGH FIBER CEREAL': 0.366667, 'TACO SEASONING MIX': 0.99 * 0.192622}
vegan_min_tj_male = {'FROSTED SHREDDED BITE SIZE WHEATS': 2.99 * 1.2, 'INNER BEAN SNACK': 1.50 * 4.135907, 
                     'FUJI APPLE SLICES': 2.99 * 0.160723,'TACO SEASONING MIX': 0.99 * 0.34093}
allergen_free_min_tj_male = {'SUPER SEED & ANCIENT GRAIN BLEND': 3.99 *1.024855, 'INNER BEAN SNACK': 1.50 * 7.371901, 
                             'FUJI APPLE SLICES': 2.99 * 0.231839,'HEMP SEED, RAW SHELLED': 6.49 * 1.2, 'NON-DAIRY RICE BEVERAGE': 2.99 *3.870968}

# Trader Joes Min Cost for Women
omnivore_min_tj_female = {'FROSTED SHREDDED BITE SIZE WHEATS': 2.99 * 0.833333, 'INNER BEAN SNACK': 1.50 * 4.258366, 
                   'FUJI APPLE SLICES': 2.99 * 0.115011, 'HIGH FIBER CEREAL': 0.266667, 'TACO SEASONING MIX': 0.99 * 0.212742}
veg_min_tj_female = {'FROSTED SHREDDED BITE SIZE WHEATS': 2.99 * 0.833333, 'INNER BEAN SNACK': 1.50 * 4.258366, 
                   'FUJI APPLE SLICES': 2.99 * 0.115011, 'HIGH FIBER CEREAL': 0.266667, 'TACO SEASONING MIX': 0.99 * 0.212742}
vegan_min_tj_female = {'FROSTED SHREDDED BITE SIZE WHEATS': 2.99 * 1.1, 'INNER BEAN SNACK': 1.50 * 4.169305, 
                     'FUJI APPLE SLICES': 2.99 * 0.126506,'TACO SEASONING MIX': 0.99 * 0.323620}
allergen_free_min_tj_female = {'SUPER SEED & ANCIENT GRAIN BLEND': 3.99 *1.017439, 'INNER BEAN SNACK': 1.50 * 6, 
                             'FUJI APPLE SLICES': 2.99 * 0.193199,'HEMP SEED, RAW SHELLED': 6.49 * 1.1, 
                             'NON-DAIRY RICE BEVERAGE': 2.99 *3.870968}

# Totals for Men
ominvore_min_tj_male_total = sum(omnivore_min_tj_male.values())
veg_min_tj_male_total = sum(veg_min_tj_male.values())
vegan_min_tj_male_total = sum(vegan_min_tj_male.values())
allergen_free_min_tj_male_total = sum(allergen_free_min_tj_male.values())

# Totals for Women
ominvore_min_tj_female_total = sum(omnivore_min_tj_female.values())
veg_min_tj_female_total = sum(veg_min_tj_female.values())
vegan_min_tj_female_total = sum(vegan_min_tj_female.values())
allergen_free_min_tj_female_total = sum(allergen_free_min_tj_female.values())


# Dictionary to Create Dataframe
min_cost = {'Total Cost': [ominvore_min_tj_male_total, veg_min_tj_male_total, vegan_min_tj_male_total,
                      allergen_free_min_tj_male_total, ominvore_min_tj_female_total, veg_min_tj_female_total,
                                         vegan_min_tj_female_total,  allergen_free_min_tj_female_total], \
                        'Diet':['Omnivore', 'Vegetarian', 'Vegan', 'Allergen Free',
                                'Omnivore', 'Vegetarian', 'Vegan', 'Allergen Free'],
                          'Sex': ['Male', 'Male', 'Male', 'Male', 'Female','Female','Female','Female']}

# Putting dictionary into dataframe
min_cost_df = pd.DataFrame.from_dict(min_cost)

# Facetgrid to show all at once
min_cost_facet = sns.FacetGrid(min_cost_df, col="Diet", hue = 'Sex', height=4, aspect=.5)
min_cost_facet.map(sns.barplot, "Sex", "Total Cost", order=["Male", "Female"])

# Adjust layout to prevent labels from overlapping
plt.tight_layout()

# Show the plot
plt.show()
